# %% [markdown]
# # 1. OverView of Dataset

# %% [markdown]
# ## Columns details:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Data Preprocessing:

# %% [markdown]
# ## A. Read CSV data

# %%
df = pd.read_csv("matches.csv")

# %% [markdown]
# ## B. Columns Overview:

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'winner', 'win_by_runs', 'win_by_wickets',
#        'player_of_match', 'venue', 'umpire1', 'umpire2'],
#       dtype='object')

# %% [markdown]
# ## C. Check missing Value

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               7
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# winner             4
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# umpire1            2
# umpire2            2
# dtype: int64

# %% [markdown]
# ## D. Handle missing Value:

# %%
df['umpire2'] = df['umpire2'].fillna('Unknown')
df['umpire1'] = df['umpire1'].fillna('Unknown')

df['city'] = df['city'].fillna(df['city'].mode()[0])
df['winner'] = df['winner'].fillna(df['winner'].mode()[0])

df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %% [markdown]
# ## E. Replace Data to short Form

# %%
replace_map = {
    'Sunrisers Hyderabad': 'SRH',
    'Mumbai Indians': 'MI',
    'Gujarat Lions': 'GT',
    'Rising Pune Supergiant': 'RPS',
    'Royal Challengers Bangalore': 'RCB',
    'Kolkata Knight Riders': 'KKR',
    'Delhi Daredevils': 'DD',
    'Kings XI Punjab': 'PBKS',
    'Chennai Super Kings': 'CSK',
    'Rajasthan Royals': 'RR',
    'Deccan Chargers': 'DCS',
    'Kochi Tuskers Kerala': 'KTK',
    'Pune Warriors': 'PW',
    'Rising Pune Supergiants': 'RPS',
    'Delhi Capitals': 'DC',
}
df = df.replace(replace_map)
df
# Out:
#       id    Season           city       date team1 team2 toss_winner  \
# 0      1  IPL-2017      Hyderabad   5/4/2017   SRH   RCB         RCB
# 1      2  IPL-2017           Pune   6/4/2017    MI   RPS         RPS
# 2      3  IPL-2017         Rajkot   7/4/2017    GT   KKR         KKR
# 3      4  IPL-2017         Indore   8/4/2017   RPS  PBKS        PBKS
# 4      5  IPL-2017      Bangalore   8/4/2017   RCB    DD         RCB
# ..   ...       ...            ...        ...   ...   ...         ...
# 751  752  IPL-2019         Mumbai   5/5/2019   KKR    MI          MI
# 752  753  IPL-2019        Chennai   7/5/2019   CSK    MI         CSK
# 753  754  IPL-2019  Visakhapatnam   8/5/2019   SRH    DC          DC
# 754  755  IPL-2019  Visakhapatnam  10/5/2019    DC   CSK         CSK
# 755  756  IPL-2019      Hyderabad  12/5/2019    MI   CSK          MI
#
#     toss_decision  result winner  win_by_runs  win_by_wickets player_of_match  \
# 0           field  normal    SRH           35               0    Yuvraj Singh
# 1           field  normal    RPS            0               7       SPD Smith
# 2           field  normal    KKR            0              10         CA Lynn
# 3           field  normal   PBKS            0               6      GJ Maxwell
# 4             bat  normal    RCB           15               0       KM Jadhav
# ..            ...     ...    ...          ...             ...             ...
# 751         field  normal     MI            0               9       HH Pandya
# 752           bat  normal     MI            0               6        AS Yadav
# 753         field  normal     DC            0               2         RR Pant
# 754         field  normal    CSK            0               6    F du Plessis
# 755           bat  normal     MI            1               0       JJ Bumrah
#
#                                          venue         umpire1         umpire2
# 0    Rajiv Gandhi International Stadium, Uppal     AY Dandekar        NJ Llong
# 1      Maharashtra Cricket Association Stadium  A Nand Kishore          S Ravi
# 2       Saurashtra Cricket Association Stadium     Nitin Menon       CK Nandan
# 3                       Holkar Cricket Stadium    AK Chaudhary   C Shamshuddin
# 4                        M Chinnaswamy Stadium         Unknown         Unknown
# ..                                         ...             ...             ...
# 751                           Wankhede Stadium   Nanda Kishore        O Nandan
# 752                  M. A. Chidambaram Stadium     Nigel Llong     Nitin Menon
# 753                           ACA-VDCA Stadium         Unknown         Unknown
# 754                           ACA-VDCA Stadium   Sundaram Ravi  Bruce Oxenford
# 755         Rajiv Gandhi Intl. Cricket Stadium     Nitin Menon       Ian Gould
#
# [756 rows x 16 columns]

# %%
df.head()
# Out:
#    id    Season       city      date team1 team2 toss_winner toss_decision  \
# 0   1  IPL-2017  Hyderabad  5/4/2017   SRH   RCB         RCB         field
# 1   2  IPL-2017       Pune  6/4/2017    MI   RPS         RPS         field
# 2   3  IPL-2017     Rajkot  7/4/2017    GT   KKR         KKR         field
# 3   4  IPL-2017     Indore  8/4/2017   RPS  PBKS        PBKS         field
# 4   5  IPL-2017  Bangalore  8/4/2017   RCB    DD         RCB           bat
#
#    result winner  win_by_runs  win_by_wickets player_of_match  \
# 0  normal    SRH           35               0    Yuvraj Singh
# 1  normal    RPS            0               7       SPD Smith
# 2  normal    KKR            0              10         CA Lynn
# 3  normal   PBKS            0               6      GJ Maxwell
# 4  normal    RCB           15               0       KM Jadhav
#
#                                        venue         umpire1        umpire2
# 0  Rajiv Gandhi International Stadium, Uppal     AY Dandekar       NJ Llong
# 1    Maharashtra Cricket Association Stadium  A Nand Kishore         S Ravi
# 2     Saurashtra Cricket Association Stadium     Nitin Menon      CK Nandan
# 3                     Holkar Cricket Stadium    AK Chaudhary  C Shamshuddin
# 4                      M Chinnaswamy Stadium         Unknown        Unknown

# %%
df.tail()
# Out:
#       id    Season           city       date team1 team2 toss_winner  \
# 751  752  IPL-2019         Mumbai   5/5/2019   KKR    MI          MI
# 752  753  IPL-2019        Chennai   7/5/2019   CSK    MI         CSK
# 753  754  IPL-2019  Visakhapatnam   8/5/2019   SRH    DC          DC
# 754  755  IPL-2019  Visakhapatnam  10/5/2019    DC   CSK         CSK
# 755  756  IPL-2019      Hyderabad  12/5/2019    MI   CSK          MI
#
#     toss_decision  result winner  win_by_runs  win_by_wickets player_of_match  \
# 751         field  normal     MI            0               9       HH Pandya
# 752           bat  normal     MI            0               6        AS Yadav
# 753         field  normal     DC            0               2         RR Pant
# 754         field  normal    CSK            0               6    F du Plessis
# 755           bat  normal     MI            1               0       JJ Bumrah
#
#                                   venue        umpire1         umpire2
# 751                    Wankhede Stadium  Nanda Kishore        O Nandan
# 752           M. A. Chidambaram Stadium    Nigel Llong     Nitin Menon
# 753                    ACA-VDCA Stadium        Unknown         Unknown
# 754                    ACA-VDCA Stadium  Sundaram Ravi  Bruce Oxenford
# 755  Rajiv Gandhi Intl. Cricket Stadium    Nitin Menon       Ian Gould

# %% [markdown]
# ## F. Data types of all columns

# %%
print(df.dtypes)
# Out:
# id                  int64
# Season             object
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# dtype: object

# %% [markdown]
# ## G. Data information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             756 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   winner           756 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  752 non-null    object
#  13  venue            756 non-null    object
#  14  umpire1          756 non-null    object
#  15  umpire2          756 non-null    object
# dtypes: int64(3), object(13)
# memory usage: 94.6+ KB

# %% [markdown]
# ## H. Check and Handle Duplicates

# %%
df.duplicated().sum()
df = df.drop_duplicates()
df
# Out:
#       id    Season           city       date team1 team2 toss_winner  \
# 0      1  IPL-2017      Hyderabad   5/4/2017   SRH   RCB         RCB
# 1      2  IPL-2017           Pune   6/4/2017    MI   RPS         RPS
# 2      3  IPL-2017         Rajkot   7/4/2017    GT   KKR         KKR
# 3      4  IPL-2017         Indore   8/4/2017   RPS  PBKS        PBKS
# 4      5  IPL-2017      Bangalore   8/4/2017   RCB    DD         RCB
# ..   ...       ...            ...        ...   ...   ...         ...
# 751  752  IPL-2019         Mumbai   5/5/2019   KKR    MI          MI
# 752  753  IPL-2019        Chennai   7/5/2019   CSK    MI         CSK
# 753  754  IPL-2019  Visakhapatnam   8/5/2019   SRH    DC          DC
# 754  755  IPL-2019  Visakhapatnam  10/5/2019    DC   CSK         CSK
# 755  756  IPL-2019      Hyderabad  12/5/2019    MI   CSK          MI
#
#     toss_decision  result winner  win_by_runs  win_by_wickets player_of_match  \
# 0           field  normal    SRH           35               0    Yuvraj Singh
# 1           field  normal    RPS            0               7       SPD Smith
# 2           field  normal    KKR            0              10         CA Lynn
# 3           field  normal   PBKS            0               6      GJ Maxwell
# 4             bat  normal    RCB           15               0       KM Jadhav
# ..            ...     ...    ...          ...             ...             ...
# 751         field  normal     MI            0               9       HH Pandya
# 752           bat  normal     MI            0               6        AS Yadav
# 753         field  normal     DC            0               2         RR Pant
# 754         field  normal    CSK            0               6    F du Plessis
# 755           bat  normal     MI            1               0       JJ Bumrah
#
#                                          venue         umpire1         umpire2
# 0    Rajiv Gandhi International Stadium, Uppal     AY Dandekar        NJ Llong
# 1      Maharashtra Cricket Association Stadium  A Nand Kishore          S Ravi
# 2       Saurashtra Cricket Association Stadium     Nitin Menon       CK Nandan
# 3                       Holkar Cricket Stadium    AK Chaudhary   C Shamshuddin
# 4                        M Chinnaswamy Stadium         Unknown         Unknown
# ..                                         ...             ...             ...
# 751                           Wankhede Stadium   Nanda Kishore        O Nandan
# 752                  M. A. Chidambaram Stadium     Nigel Llong     Nitin Menon
# 753                           ACA-VDCA Stadium         Unknown         Unknown
# 754                           ACA-VDCA Stadium   Sundaram Ravi  Bruce Oxenford
# 755         Rajiv Gandhi Intl. Cricket Stadium     Nitin Menon       Ian Gould
#
# [756 rows x 16 columns]

# %% [markdown]
# ## I. Describe dataset

# %%
df.describe()
# Out:
#                id  win_by_runs  win_by_wickets
# count  756.000000   756.000000      756.000000
# mean   378.500000    13.283069        3.350529
# std    218.382692    23.471144        3.387963
# min      1.000000     0.000000        0.000000
# 25%    189.750000     0.000000        0.000000
# 50%    378.500000     0.000000        4.000000
# 75%    567.250000    19.000000        6.000000
# max    756.000000   146.000000       10.000000

# %% [markdown]
# ## J. shape of Dataset

# %%
df.shape
# Out:
# (756, 16)

# %% [markdown]
# ## K. All Seasion

# %%
#Finding the number of seasons
df['Season'].unique()
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %% [markdown]
# ## L. Finding which IPL team scored the maximum runs

# %%
df.iloc[df['win_by_runs'].idxmax()]
# Out:
# id                               44
# Season                     IPL-2017
# city                          Delhi
# date                       6/5/2017
# team1                            MI
# team2                            DD
# toss_winner                      DD
# toss_decision                 field
# result                       normal
# winner                           MI
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# Name: 43, dtype: object

# %% [markdown]
# ## M. which team won by scoring maximum wickets

# %%
df.iloc[df['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# Season                                           IPL-2017
# city                                               Rajkot
# date                                             7/4/2017
# team1                                                  GT
# team2                                                 KKR
# toss_winner                                           KKR
# toss_decision                                       field
# result                                             normal
# winner                                                KKR
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# umpire2                                         CK Nandan
# Name: 2, dtype: object

# %% [markdown]
# # 3. EDA (Exploratory Data Analysis):

# %% [markdown]
# ## Univariant

# %% [markdown]
# ### Q1.Which season had the most matches?

# %%
sns.countplot(x = 'Season', data = df, hue='Season', palette='jet_r')
plt.xticks(rotation = 90)
plt.xlabel('Seasion in year')
plt.ylabel('Total number of Season')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q2. Which city hosted the most matches?

# %%
sns.countplot(x = 'city', data = df, hue='city', palette='jet_r')
plt.xticks(rotation = 90)
plt.title('Matches Hosted per City')
plt.xlabel('City')
plt.ylabel('Total Number of Matches')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q3. Which team appears most frequently as Team1?

# %%
team1_counts = df['team1'].value_counts()
team1_counts.plot(kind='pie', autopct='%1.1f%%', radius=1.5)
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q4. Which team appears most frequently as Team2?

# %%
team2_counts = df['team2'].value_counts()
team2_counts.plot(kind='bar')
plt.xlabel('Team2')
plt.ylabel('Number of Matches')
plt.title('Frequency of Team2 Appearances')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q5. Which team won the toss most often?

# %%
sns.countplot(x = 'toss_winner', data = df, hue='toss_winner', palette='jet_r')
plt.xticks(rotation = 90)
plt.title('Toss Wins by Team')
plt.xlabel('Teams')
plt.ylabel('Number of Toss Wins')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q6. Which toss decision was chosen most often (bat/field)

# %%
sns.countplot(x = 'toss_decision', data = df, hue='toss_decision', palette='jet_r')
plt.title('Toss Decision Counts')
plt.xlabel('Toss Decision')
plt.ylabel('Frequency')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q7. Which result type occurred most frequently (normal/tie/no result)

# %%
result_counts = df['result'].value_counts()
result_counts.plot(kind='bar')
plt.xlabel('Result Type')
plt.ylabel('Frequency')
plt.title('Match Result Counts')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q8. Which team won most matches?

# %%
sns.countplot(x = 'winner', data = df, hue='winner', palette='jet_r')
plt.xticks(rotation = 90)
plt.title('Matches Won by Team')
plt.xlabel('Teams')
plt.ylabel('Number of Wins')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q9. Which stadium hosted the most matches?

# %%
venue_counts = df['venue'].value_counts()
venue_counts.plot(kind='bar', fontsize=8)
plt.xlabel('Venue')
plt.ylabel('Number of Matches')
plt.title('Matches Hosted per Venue')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q10. Distribution of win margins by runs

# %%
df['win_by_runs'].plot(kind='hist')
plt.xlabel('Win by Runs')
plt.ylabel('Frequency')
plt.title('Distribution of Win Margins by Runs')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q11. Distribution of win margins by Wickets

# %%
df['win_by_wickets'].plot(kind='hist')
plt.xlabel('Win by Wickets')
plt.ylabel('Frequency')
plt.title('Distribution of Win Margins by Runs')
plt.savefig("1.png",  bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q12. Top 10 Most frequently used umpire1.

# %%
df['umpire1'].value_counts().head(10).plot(kind='pie', autopct='%1.1f%%')

plt.title('Proportion of Umpire1 Selection')
plt.savefig("1.png", bbox_inches="tight", dpi = 300, transparent=True)
plt.show()

# %% [markdown]
# ### Q13. Top 10 Most frequently used umpire2.

# %% [markdown]
# # Bivariate
