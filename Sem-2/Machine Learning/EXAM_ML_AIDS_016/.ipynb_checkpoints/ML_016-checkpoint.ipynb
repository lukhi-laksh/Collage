# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# # Q1.Data Exploration:

# %% [markdown]
# ## I.Load the dataset and display basic statistics.

# %% [markdown]
# ### i. Load Dataset

# %%
df = pd.read_csv('Dry_Bean_Dataset.csv')

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %% [markdown]
# ### ii. Basic Statistics

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860154       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# ...

# %% [markdown]
# ## II.Identify the number of records, missing values, and data types.

# %% [markdown]
# ### i.number of records

# %%
print("\nTotal Records:", df.shape[0])
print("Total Columns:", df.shape[1])
# Out:
# Total Records: 13611
# Total Columns: 17

# %% [markdown]
# ### ii. Missing Values

# %%
df.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %% [markdown]
# ### iii. Data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %% [markdown]
# ## Duplicated Data and Remove Them

# %%
df.duplicated().sum()
# Out:
# 68

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Q2. Handling Missing Values:

# %% [markdown]
# ## I. Identify missing values and impute or drop them as required.

# %%
# for col in df.columns:
#    if df[col].dtype != 'object':
#        df[col].fillna(df[col].mean(), inplace=True)
#    else:
#        df[col].fillna(df[col].mode()[0], inplace=True)

# %% [markdown]
# # Q3. Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 1. Univariate Analysis

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['MinorAxisLength'], bins=20)
plt.title("Distribution of Numerical Features")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Extent'], bins=20)
plt.title("Distribution of Numerical Features")
plt.show()

# %% [markdown]
# ## 2.Bivariate Analysis

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='EquivDiameter', y='ConvexArea', data=df)
plt.title("Area vs Perimeter")
plt.show()

# %% [markdown]
# ## 3. Correlation Heatmap

# %%
corr = df.drop(columns=['Class']).corr()

# %%
plt.figure(figsize=(14,10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## 4. Bar plot for categorical variables

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Class', data=df)
plt.title("Class Distribution")
plt.xticks(rotation=45)
plt.show()

df['Class'].value_counts()
# Out:
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1860
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: Class, dtype: int64

# %% [markdown]
# ## 5. Boxplot for Outlier Detection

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'Perimeter', data = df)
plt.xticks(rotation=90)
plt.title("Outlier Detection")
plt.show()

# %% [markdown]
# # Q4. Model Building:

# %% [markdown]
# ## 1. Convert categorical variables into numerical representations

# %%
le = LabelEncoder()
df['Class'] = le.fit_transform(df['Class'])

X = df.drop("Class", axis=1)
y = df["Class"]

# %% [markdown]
# ## Feature Scaling

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 2. Perform train-test split (e.g., 80-20 split).

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ## 3. Train at least four classification models:

# %% [markdown]
# ### i. Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=5000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)
print("\nClassification report:\n", classification_report(y_test, y_pred))
plt.figure(figsize=(10, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
plt.show()
# Out:
# Accuracy: 0.9191583610188261
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       265
#            1       1.00      1.00      1.00       104
#            2       0.91      0.94      0.93       326
#            3       0.93      0.91      0.92       709
#            4       0.96      0.94      0.95       372
#            5       0.93      0.94      0.94       406
#            6       0.86      0.88      0.87       527
#
#     accuracy                           0.92      2709
#    macro avg       0.93      0.93      0.93      2709
# weighted avg       0.92      0.92      0.92      2709

# %% [markdown]
# ### ii. Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=300, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)
print("\nClassification report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9198966408268734
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91       265
#            1       1.00      1.00      1.00       104
#            2       0.92      0.94      0.93       326
#            3       0.91      0.92      0.92       709
#            4       0.96      0.94      0.95       372
#            5       0.94      0.96      0.95       406
#            6       0.87      0.86      0.86       527
#
#     accuracy                           0.92      2709
#    macro avg       0.93      0.93      0.93      2709
# weighted avg       0.92      0.92      0.92      2709
#
#
# Confusion Matrix:
#  [[237   0  17   0   1   3   7]
#  [  0 104   0   0   0   0   0]
#  [ 11   0 305   0   5   2   3]
#  [  0   0   0 654   0  11  44]
#  [  1   0  10   3 349   0   9]
#  [  4   0   0   6   0 389   7]
#  [  4   0   0  54   7   8 454]]

# %% [markdown]
# ### iii. SVM Model

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)
print("\nClassification report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9198966408268734
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91       265
#            1       1.00      1.00      1.00       104
#            2       0.92      0.94      0.93       326
#            3       0.91      0.92      0.92       709
#            4       0.96      0.94      0.95       372
#            5       0.94      0.96      0.95       406
#            6       0.87      0.86      0.86       527
#
#     accuracy                           0.92      2709
#    macro avg       0.93      0.93      0.93      2709
# weighted avg       0.92      0.92      0.92      2709
#
#
# Confusion Matrix:
#  [[237   0  17   0   1   3   7]
#  [  0 104   0   0   0   0   0]
#  [ 11   0 305   0   5   2   3]
#  [  0   0   0 654   0  11  44]
#  [  1   0  10   3 349   0   9]
#  [  4   0   0   6   0 389   7]
#  [  4   0   0  54   7   8 454]]

# %%
import pickle

# %%
with open('SVC_model.pkl', 'wb') as m:
    pickle.dump(svm, m)

# %%
with open('SVC_model.pkl', 'rb') as m:
    model_load = pickle.load(m)

# %%
model_load.predict([[28395, 610.291, 208.1781167, 173.888747, 1.197191424, 0.549812187, 28715, 190.1410973, 0.763922518, 0.988855999, 0.958027126, 0.913357755, 0.007331506, 0.003147289, 0.834222388,0.99872388]])[0]
# Out:
# 4
